# %%
N = int(input())
nameList = []

for i in range(N):
    name = input()
    nameList.append(name)
    
patturn = ""

for i in range(len(nameList)):
    if (nameList)

print(patturn)
# Out:
# 3
# config.sys
# config.inf
# configures
# config.sys
